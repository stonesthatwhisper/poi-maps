# %%
# !pip install folium

# %%
# !pip install --force-reinstall numpy==1.26.4
# Out:
# ...
#      |████████████████████████████████| 20.6 MB 14.9 MB/s eta 0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# statsmodels 0.12.2 requires scipy>=1.1, which is not installed.
# seaborn 0.11.1 requires scipy>=1.0, which is not installed.
# scikit-image 0.18.1 requires scipy>=1.0.1, which is not installed.
# gensim 4.0.1 requires scipy>=0.18.1, which is not installed.
# datashader 0.16.3 requires scipy, which is not installed.
# daal4py 2023.1.1 requires scikit-learn>=0.24, which is not installed.
# ...

# %%
import folium

# %%
import folium

# Initialize the map centered around the approximate geographical center of the locations
#m = folium.Map(location=[37.7749, -122.4194], zoom_start=8)

# List of game locations with coordinates
ecnl_locations = [
    {"name": "College of Marin - Stadium", "coords": [37.9485, -122.5081]},
    {"name": "Santa Clara Youth Soccer Park - Field 2", "coords": [37.4069, -121.9766]},
    {"name": "Placer High School - Stadium", "coords": [38.8994, -121.0746]},
    {"name": "Alisal High School - Field 1 Stadium", "coords": [36.6966, -121.6148]},
    {"name": "San Juan Soccer Complex - Blue", "coords": [38.7083, -121.1355]},
    {"name": "Davis Legacy Soccer Complex - Field 9", "coords": [38.5463, -121.7358]},
    {"name": "Trione Fields - Trione West", "coords": [38.4807, -122.7044]},
    {"name": "Foothill College - Top Hill Soccer Field", "coords": [37.3625, -122.1277]},
    {"name": "San Joaquin Memorial- 1406 N. Fresno St. Fresno, C - field 1", "coords": [36.7679, -119.7796]},
    {"name": "Skyline High School - Stadium", "coords": [37.7823, -122.1815]},
    {"name": "Newark Sportsfield Park - SFT #1 11v11", "coords": [37.5219, -122.0256]},
    {"name": "Provident Field @ MSC - Lower", "coords": [37.6585, -121.8781]},
]

# Add markers for each location
#for location in ecnl_locations:
#    folium.Marker(location["coords"], popup=location["name"]).add_to(m)


# Coordinates for each location
mlsn_locations = [
    {"name": "SF Glens TI Field", "coords": [37.8253, -122.3706]},
    {"name": "Mary Grogan Community Park - Field 2", "coords": [37.6746, -121.0158]},
    {"name": "De Anza College - Stadium", "coords": [37.3216, -122.0475]},
    {"name": "Monte Vista Christian School - Mustang Stadium", "coords": [36.9363, -121.7625]},
    {"name": "Mayfield Soccer Complex - Mayfield South", "coords": [37.4072, -122.0945]},
    {"name": "Granite Regional Park - Turf", "coords": [38.5535, -121.4064]},
    {"name": "Ohlone College - Soccer Field", "coords": [37.5260, -121.9281]},
    {"name": "Notre Dame de Namur University - Koret Field", "coords": [37.5148, -122.2907]},
    {"name": "Concord High - Stadium", "coords": [37.9621, -122.0137]},
    {"name": "Cosumnes River College Stadium - Stadium Field", "coords": [38.4799, -121.4254]},
    {"name": "Wilder Fields - Field 2 - Wilder 2", "coords": [37.8822, -122.1884]},
    {"name": "Elsie Allen High School", "coords": [38.4131, -122.7452]},
]

# Create a map centered around the Bay Area
map_center = [37.7749, -122.4194]
game_map = folium.Map(location=map_center, zoom_start=8)

# Add markers for each location
for location in ecnl_locations:
    folium.Marker(
        location=location["coords"],
        popup=location["name"],
        icon=folium.Icon(color='darkgreen', prefix='fa',icon='e')
    ).add_to(game_map)

#for location in mlsn_locations:
#    folium.Marker(
#        location=location["coords"],
#        popup=location["name"],
#        icon=folium.Icon(color='lightblue', prefix='fa',icon='m')
#    ).add_to(game_map)


# Save the map to an HTML file
map_path = "./games_map_ecnl.html"
game_map.save(map_path)

print(map_path)
game_map
# Out:
# ./games_map_ecnl.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
help(folium.Icon)
# Out:
# Help on class Icon in module folium.map:
#
# class Icon(branca.element.MacroElement)
#  |  Icon(color: str = 'blue', icon_color: str = 'white', icon: str = 'info-sign', angle: int = 0, prefix: str = 'glyphicon', **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |
#  |  Creates an Icon object that will be rendered
#  |  using Leaflet.awesome-markers.
#  |
#  |  Parameters
#  |  ----------
#  |  color : str, default 'blue'
#  |      The color of the marker. You can use:
#  |
#  |          ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
#  |           'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
#  |           'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen',
#  |           'gray', 'black', 'lightgray']
#  |
#  |  icon_color : str, default 'white'
#  |      The color of the drawing on the marker. You can use colors above,
#  |      or an html color code.
#  |  icon : str, default 'info-sign'
#  |      The name of the marker sign.
# ...
